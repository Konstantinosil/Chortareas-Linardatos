# %% [markdown]
# <a href="https://colab.research.google.com/github/Konstantinosil/Chortareas-Linardatos/blob/main/Euro_Area_Chortareas_%26_Linardatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install filterpy==1.4.5 scikit-learn==1.4.2 statsmodels==0.14.1

import numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path; from scipy.optimize import minimize
from filterpy.kalman import KalmanFilter
from sklearn.decomposition import PCA; from sklearn.preprocessing import StandardScaler
from statsmodels.regression.linear_model import OLS; from statsmodels.tools.tools import add_constant
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox, het_arch
from statsmodels.tsa.ar_model import AutoReg
from IPython.display import display

SEED = 42
rng  = np.random.default_rng(SEED);  np.random.seed(SEED)

DATA = Path("/content/data shadow new eu.xlsx")
xls  = pd.ExcelFile(DATA)

def _prep(sheet, cols):
    df = pd.read_excel(xls, sheet, header=1)
    df.columns = cols
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
    return df.dropna(subset=["Date"]).set_index("Date")

ser = {
    "SR" : _prep("Shadow Rates EU", ["Date","SR EU"]),
    "INF": _prep("Inflation Data EU", ["Date","INF EU"]),
    "UN" : _prep("Unemployment Data EU", ["Date","UNEM EU"]),
    "CDS": _prep("Sovereign CDS Spreads EU", ["Date","CDS EU"]),
    "GDP": _prep("Real GDP EU", ["Date","GDP EU"]),
    "EX" : _prep("Exchange Rates EU", ["Date","EX EU"]),
    "3M" : _prep("3M",  ["Date","3M EU"]),
    "6M" : _prep("6M",  ["Date","6M EU"]),
    "1Y" : _prep("1Y",  ["Date","1Y EU"]),
    "2Y" : _prep("2Y",  ["Date","2Y EU"]),
    "5Y" : _prep("5Y",  ["Date","5Y EU"]),
    "7Y" : _prep("7Y",  ["Date","7Y EU"]),
    "10Y": _prep("10Y", ["Date","10Y EU"]),
    "30Y": _prep("30Y", ["Date","30Y EU"]),
}

df = pd.concat(ser.values(), axis=1).interpolate("linear")
macro = ["INF EU","UNEM EU","EX EU","CDS EU","GDP EU"]
ylds  = ["3M EU","6M EU","1Y EU","2Y EU","5Y EU","7Y EU","10Y EU","30Y EU"]
df    = df.dropna(subset=["SR EU"] + macro + ylds)

y_df, m_df = df[ylds].copy(), df[macro].copy()

var_list = ylds + macro
tbl_station, tbl_ac, tbl_arch = [], [], []

for v in var_list:
    s0 = df[v].dropna()
    adf0 = adfuller(s0, autolag='AIC'); stat0, p0 = adf0[0], adf0[1]

    if p0 < .05:
        tbl_station.append([v, stat0, p0, 'Stat']);  s_final = s0
    else:
        s1 = s0.diff().dropna()
        adf1 = adfuller(s1, autolag='AIC')
        tbl_station += [[f'{v}(orig)',stat0,p0,'NOT stat'],
                        [f'{v}(Δ1)',adf1[0],adf1[1],
                         'Stat' if adf1[1]<.05 else 'NOT']]
        s_final = s1

    lb_p   = acorr_ljungbox(s_final, lags=[10], return_df=True)['lb_pvalue'].iloc[0]
    arch_p = het_arch(s_final, maxlag=10)[1]
    tbl_ac.append([v, lb_p,   'Sig' if lb_p<.05  else 'OK'])
    tbl_arch.append([v, arch_p,'Sig' if arch_p<.05 else 'OK'])

print("\n=== ADF ===");   display(pd.DataFrame(tbl_station, columns=['Var','ADF','p','Res']))
print("\n=== LB  ===");  display(pd.DataFrame(tbl_ac,      columns=['Var','p','AC?']))
print("\n=== ARCH ==="); display(pd.DataFrame(tbl_arch,    columns=['Var','p','ARCH?']))

if y_df.abs().max().max() > 20: y_df /= 100
low, upp = y_df.mean()-3*y_df.std(), y_df.mean()+3*y_df.std()
y_df = y_df.clip(lower=low, upper=upp, axis=1)
m_z  = pd.DataFrame(StandardScaler().fit_transform(m_df),
                    index=m_df.index, columns=m_df.columns)

def _beta(y,z):
    X = add_constant(z); return {c: OLS(y[c],X).fit().params.values for c in y}

def _pca(y): return PCA(1,random_state=SEED).fit_transform(y).ravel()

def _sim(n,r0,z,β,ψ,lb=-2):
    κ,σ,λ,μ,s,θ0,θ1,θ2 = ψ; z0,z1 = 102,805
    S=np.empty(n); S[0]=r0
    for t in range(1,n):
        θ = θ0 if t<z0 else (θ1 if t<=z1 else θ2)
        S[t]=S[t-1]+κ*(θ-S[t-1])+σ*rng.normal()
        if rng.random()<λ: S[t]+=rng.normal(μ,s)
        if S[t]<lb: S[t]=lb+0.3*(S[t]-lb)
        Xt=z.iloc[t].values
        S[t]+=0.5*np.mean([Xt@β[m][1:] for m in β])
    return S

def _kalman(x):
    kf=KalmanFilter(dim_x=1,dim_z=1)
    kf.x=[[x[0]]]; kf.F=kf.H=np.eye(1); kf.P*=100; kf.R[:]=1; kf.Q[:]=0.01
    out=[]
    for v in x: kf.predict(); kf.update([[v]]); out.append(kf.x[0,0])
    return np.array(out)

β   = _beta(y_df,m_z); pca = _pca(y_df)
print("\n=== β̂m (macro loading per maturity) ===")
for m, coef in β.items():
    print(f"{m:>5}: {coef[1]:+.4f}")
pca = _pca(y_df)
θ0, θ1, θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()

θ0,θ1,θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()
x0  = [0.15,0.015,0.005,0.10,0.05, θ0,θ1,θ2]
bnd = [(1e-4,1),(1e-4,0.05),(0,0.1),(-.5,.5),(1e-4,0.2),(-5,5),(-5,5),(-5,5)]
obj = lambda p: ((_sim(len(pca),pca[0],m_z,β,p)-pca)**2).sum()
ψhat= minimize(obj,x0,bounds=bnd,method='L-BFGS-B',
               options={'maxiter':500}).x

S     = _sim(len(pca),pca[0],m_z,β,ψhat)
S_sm  = _kalman(S)
final = pd.Series(0.7*pca+0.3*S_sm,index=df.index,name='Final SR')

print("\nψ̂:",np.round(ψhat,4))
display(final.head())

ws   = np.arange(0.50, 0.95, 0.05)
rmse = []

for w in ws:
    shadow = w*pca + (1-w)*S_sm
    errs = []
    for m in ylds:
        y_hat = OLS(y_df[m], add_constant(shadow)).fit().fittedvalues
        errs.append(((y_df[m]-y_hat)**2).mean())
    rmse.append(np.sqrt(np.mean(errs))*1e4)

grid = pd.DataFrame({"w": ws, "RMSE_bp": rmse})
print(grid.round(2))

grid.plot(x="w", y="RMSE_bp", marker="o", figsize=(4,3.5))
plt.ylabel("mean cross-section RMSE (bp)"); plt.tight_layout(); plt.show()

plt.figure(figsize=(5,3.5))
plt.bar(range(1,9), PCA().fit(y_df).explained_variance_ratio_)
plt.xlabel('PC'); plt.ylabel('Explained var share')
plt.title('Scree – EU Yield Curve'); plt.tight_layout(); plt.show()

plt.figure(figsize=(11,5))
plt.plot(df.index,final,label='Final SR')
plt.plot(df.index,pca,'--',label='PCA'); plt.grid(); plt.legend()
plt.title('EU shadow-rate'); plt.show()

start,end='2009-01-01','2022-08-01'; alpha=0.05
ewma = final.ewm(alpha=alpha,adjust=False).mean().loc[start:end]
wu   = df['SR EU'].loc[start:end]

plt.figure(figsize=(11,5))
plt.plot(final.resample('M').mean().loc[start:end],lw=2,label='Final (monthly)')
plt.plot(wu.resample('M').last(),'--',label='Wu-Xia'); plt.grid(); plt.legend()
plt.ylabel('%'); plt.title('Final vs Wu-Xia (monthly)'); plt.show()

plt.figure(figsize=(11,5))
plt.plot(ewma,lw=2,label=f'Final EWMA (α={alpha})')
plt.plot(wu,'--',label='Wu-Xia'); plt.grid(); plt.legend()
plt.ylabel('%'); plt.title('Final EWMA vs Wu-Xia (daily)'); plt.show()

fit_tbl=[]
for m in ylds:
    rmse_f = np.sqrt(((OLS(y_df[m], add_constant(final)).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    rmse_w = np.sqrt(((OLS(y_df[m], add_constant(df['SR EU'])).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    fit_tbl.append([m, rmse_f, rmse_w])

fit_df = pd.DataFrame(fit_tbl, columns=['Maturity','RMSE_final','RMSE_WX'])
print("\n=== In-sample cross-section RMSE (bp) ==="); display(fit_df)

TEST_START = '2023-01-01'
train      = final.loc[:TEST_START]
test_idx   = final.loc[TEST_START:].index
n_train    = len(train)

oos_len   = len(test_idx)

ar1 = AutoReg(train, lags=1, old_names=False).fit()

pred_path = ar1.forecast(steps=oos_len)
pred_path.index = test_idx

fc_df = pd.DataFrame({f'h{h}': pred_path.shift(h-1)
                      for h in range(1, 13)},
                     index=test_idx)

oos_tbl=[]
for m in ylds:
    a,b = OLS(y_df[m].loc[:TEST_START], add_constant(train)).fit().params
    act = y_df[m].loc[TEST_START:]
    for h in range(1,13):
        rmse = np.sqrt(((a + b*fc_df[f'h{h}'] - act)**2).mean())*1e4
        oos_tbl.append([m, h, rmse])

oos_df = (pd.DataFrame(oos_tbl, columns=['Maturity','h','RMSE_bp'])
            .pivot(index='Maturity', columns='h', values='RMSE_bp')
            .reindex(ylds))

print("\n=== OOS RMSE (bp) – forecast horizon h = 1…12 months ===")
display(oos_df.round(2))

OUT = Path("/content/shadow_rate_eu.csv")
final.to_csv(OUT, index_label="Date")
final.to_excel("/content/shadow_rate_eu.xlsx", sheet_name="EU SR")

print(f"\n✓ Shadow-rate series written to:  {OUT.resolve()}")
print(f"  Rows written: {len(final):,}")
# Out:
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# === ADF ===
# /tmp/ipython-input-2043763625.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
#               Var        ADF             p       Res
# 0     3M EU(orig)  -1.966270  3.015553e-01  NOT stat
# 1       3M EU(Δ1) -12.881831  4.641304e-24      Stat
# 2     6M EU(orig)  -2.106384  2.419551e-01  NOT stat
# 3       6M EU(Δ1) -13.115691  1.600921e-24      Stat
# 4     1Y EU(orig)  -2.141170  2.282852e-01  NOT stat
# 5       1Y EU(Δ1) -13.223977  9.887211e-25      Stat
# 6     2Y EU(orig)  -2.174103  2.157783e-01  NOT stat
# 7       2Y EU(Δ1) -13.079758  1.881449e-24      Stat
# 8     5Y EU(orig)  -2.002812  2.853415e-01  NOT stat
# 9       5Y EU(Δ1) -13.271080  8.035126e-25      Stat
# 10    7Y EU(orig)  -1.868190  3.471703e-01  NOT stat
# 11      7Y EU(Δ1) -13.698446  1.303409e-25      Stat
# 12   10Y EU(orig)  -1.701928  4.301193e-01  NOT stat
# 13     10Y EU(Δ1) -15.335681  3.891829e-28      Stat
# 14   30Y EU(orig)  -1.687119  4.377613e-01  NOT stat
# 15     30Y EU(Δ1) -16.549403  1.951270e-29      Stat
# 16   INF EU(orig)   0.414048  9.820128e-01  NOT stat
# 17     INF EU(Δ1)  -8.505836  1.203638e-13      Stat
# 18  UNEM EU(orig)  -0.855918  8.021426e-01  NOT stat
# 19    UNEM EU(Δ1)  -4.507256  1.907878e-04      Stat
# 20          EX EU  -4.841728  4.522386e-05      Stat
# 21   CDS EU(orig)  -2.698867  7.423460e-02  NOT stat
# 22     CDS EU(Δ1) -11.002975  6.610820e-20      Stat
# 23   GDP EU(orig)  -1.614040  4.758551e-01  NOT stat
# 24     GDP EU(Δ1)  -6.351300  2.606917e-08      Stat
# === LB  ===
#         Var              p  AC?
# 0     3M EU   0.000000e+00  Sig
# 1     6M EU   0.000000e+00  Sig
# 2     1Y EU   0.000000e+00  Sig
# 3     2Y EU  5.310339e-128  Sig
# 4     5Y EU   1.687226e-73  Sig
# 5     7Y EU   1.540112e-81  Sig
# 6    10Y EU   7.307992e-89  Sig
# 7    30Y EU   2.281397e-63  Sig
# 8    INF EU   0.000000e+00  Sig
# 9   UNEM EU   0.000000e+00  Sig
# 10    EX EU   0.000000e+00  Sig
# 11   CDS EU   7.158456e-55  Sig
# 12   GDP EU   0.000000e+00  Sig
# === ARCH ===
#         Var              p ARCH?
# 0     3M EU  1.696081e-122   Sig
# 1     6M EU  1.323065e-144   Sig
# 2     1Y EU   1.745783e-94   Sig
# 3     2Y EU  6.138335e-103   Sig
# 4     5Y EU  1.312643e-117   Sig
# 5     7Y EU  1.113906e-107   Sig
# 6    10Y EU   8.681232e-97   Sig
# 7    30Y EU   3.594336e-57   Sig
# 8    INF EU   0.000000e+00   Sig
# 9   UNEM EU   0.000000e+00   Sig
# 10    EX EU   0.000000e+00   Sig
# 11   CDS EU  5.423597e-139   Sig
# 12   GDP EU   0.000000e+00   Sig
# === β̂m (macro loading per maturity) ===
# 3M EU: +1.5684
# 6M EU: +1.5506
# 1Y EU: +1.4670
# 2Y EU: +1.2873
# 5Y EU: +0.9974
# 7Y EU: +0.9113
# 10Y EU: +0.8499
# 30Y EU: +0.5738
#
# ψ̂: [ 0.15    0.015   0.005   0.1     0.05    5.      5.     -0.2341]
# Date
# 2008-07-22    7.925374
# 2008-07-23    8.005088
# 2008-07-24    8.083726
# 2008-07-25    8.164605
# 2008-07-28    8.244170
# Name: Final SR, dtype: float64
#       w  RMSE_bp
# 0  0.50  6385.76
# 1  0.55  6120.17
# 2  0.60  5870.62
# 3  0.65  5641.02
# 4  0.70  5435.19
# 5  0.75  5256.62
# 6  0.80  5108.25
# 7  0.85  4992.26
# 8  0.90  4909.88
# /tmp/ipython-input-2043763625.py:158: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.plot(final.resample('M').mean().loc[start:end],lw=2,label='Final (monthly)')
# /tmp/ipython-input-2043763625.py:159: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.plot(wu.resample('M').last(),'--',label='Wu-Xia'); plt.grid(); plt.legend()
# === In-sample cross-section RMSE (bp) ===
#   Maturity   RMSE_final       RMSE_WX
# 0    3M EU  7311.345487  10126.587826
# 1    6M EU  7030.856655   9903.318701
# 2    1Y EU  6115.446874   9227.966477
# 3    2Y EU  4203.429672   7976.358549
# 4    5Y EU  2235.850303   6457.523437
# 5    7Y EU  3245.632877   6191.862239
# 6   10Y EU  4733.824774   6158.890868
# 7   30Y EU  6358.630391   6105.028155
# === OOS RMSE (bp) – forecast horizon h = 1…12 months ===
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:307: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# h               1         2         3         4         5         6   \
# Maturity
# 3M EU     28665.25  28672.34  28679.09  28681.64  28682.53  28681.64
# 6M EU     27497.22  27499.93  27502.21  27499.03  27495.21  27490.74
# 1Y EU     24603.07  24600.60  24597.69  24587.22  24577.87  24569.61
# 2Y EU     19114.59  19107.78  19100.60  19084.87  19071.81  19061.18
# 5Y EU      9617.14   9605.63   9594.04   9579.00   9565.75   9553.66
# 7Y EU      6499.81   6486.85   6474.07   6462.89   6451.83   6440.15
# 10Y EU     4483.69   4469.42   4455.87   4453.13   4447.94   4439.51
# 30Y EU     4745.40   4729.82   4715.77   4722.53   4726.83   4728.49
#
# h               7         8         9         10        11        12
# Maturity
# 3M EU     28678.84  28669.80  28662.42  28651.35  28636.26  28622.40
# 6M EU     27485.60  27473.55  27462.22  27449.35  27434.89  27422.81
# 1Y EU     24562.40  24547.81  24534.42  24520.85  24507.08  24496.88
# 2Y EU     19052.73  19038.08  19025.38  19012.17  18998.44  18988.84
# 5Y EU      9542.10   9529.40   9516.68   9503.45   9489.62   9477.85
# 7Y EU      6427.06   6415.68   6404.49   6393.45   6382.38   6370.18
# 10Y EU     4427.07   4420.27   4415.48   4412.68   4411.51   4403.23
# 30Y EU     4727.33   4734.64   4741.27   4756.67   4778.37   4790.43
# ✓ Shadow-rate series written to:  /content/shadow_rate_eu.csv
#   Rows written: 4,725

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from statsmodels.tsa.api import VAR
import matplotlib.pyplot as plt

file_path = '/content/favar eu.xlsx'
wu_xia_file_path = '/content/wu xia shadow rates.xlsx'

wu_xia_data = pd.ExcelFile(wu_xia_file_path)
wu_xia_eu = pd.read_excel(wu_xia_data, sheet_name='Shadow Rates EU', skiprows=1)
wu_xia_eu.columns = ['Date', 'Wu-Xia Shadow Rate EU']
wu_xia_eu['Date'] = pd.to_datetime(wu_xia_eu['Date'], errors='coerce')
wu_xia_eu = wu_xia_eu.dropna(subset=['Date']).set_index('Date')

data = pd.ExcelFile(file_path)
shadow_rates_eu = pd.read_excel(data, sheet_name='Shadow Rates EU', index_col='Date', parse_dates=True)
indeutrial_prod_eu = pd.read_excel(data, sheet_name='Industrial Production EU', index_col='Date', parse_dates=True)
cpi_eu = pd.read_excel(data, sheet_name='CPI EU', index_col='Date', parse_dates=True)
unemployment_eu = pd.read_excel(data, sheet_name='Unemployment EU', index_col='Date', parse_dates=True)
bond_yields_eu_3m = pd.read_excel(data, sheet_name='Bond Yields EU 3M', index_col='Date', parse_dates=True)
bond_yields_eu_10y = pd.read_excel(data, sheet_name='Bond Yields EU 10Y', index_col='Date', parse_dates=True)

eu_data_with_wu_xia = pd.concat([
    wu_xia_eu,
    shadow_rates_eu.rename(columns={'Shadow Rate EU': 'Proposed Shadow Rate'}),
    indeutrial_prod_eu,
    cpi_eu,
    unemployment_eu,
    bond_yields_eu_3m,
    bond_yields_eu_10y
], axis=1).dropna()

print(eu_data_with_wu_xia.columns)

def process_data_for_VAR(data, shadow_rate_col):
    diff_data = data.diff().dropna()
    diff_data.index = pd.date_range(start=diff_data.index[0], periods=len(diff_data), freq='ME')
    standardized_data = (diff_data - diff_data.mean()) / diff_data.std()

    macro_vars = standardized_data.drop(columns=[shadow_rate_col])
    pca = PCA(n_components=3)
    pca_factors = pca.fit_transform(macro_vars)

    factors = pd.DataFrame(pca_factors, index=diff_data.index, columns=['Factor1', 'Factor2', 'Factor3'])
    var_data = pd.concat([factors, diff_data[shadow_rate_col]], axis=1)
    return var_data

eu_favar_data_your_shadow = process_data_for_VAR(eu_data_with_wu_xia, shadow_rate_col='Proposed Shadow Rate')
eu_favar_data_wu_xia_shadow = process_data_for_VAR(eu_data_with_wu_xia, shadow_rate_col='Wu-Xia Shadow Rate EU')

def fit_VAR_and_analyze(data, lags=2, n_periods=10):
    """
    • Fits a VAR(lags) to the input DataFrame.
    • Prints the full coefficient tables, information criteria,
      and residual-correlation matrix.
    • Returns both the fitted VAR object and its orthogonalised IRF object.
    """
    model     = VAR(data)
    var_model = model.fit(lags)

    print("\n=== VAR({}) estimation results ===".format(lags))
    print(var_model.summary())
    print("\nCorrelation matrix of residuals")
    print(var_model.resid.corr())

    irf = var_model.irf(n_periods)
    return var_model, irf

var_your_shadow, irf_your_shadow = fit_VAR_and_analyze(
    eu_favar_data_your_shadow, lags=2, n_periods=10)

var_wu_xia, irf_wu_xia_shadow = fit_VAR_and_analyze(
    eu_favar_data_wu_xia_shadow, lags=2, n_periods=10)

print("Impulse Response for the proposed Shadow Rate (EU):")
irf_your_shadow.plot(orth=True)
plt.title("Impulse Response for the proposed Shadow Rate (EU)")
plt.show()

print("Impulse Response for Wu-Xia Shadow Rate (EU):")
irf_wu_xia_shadow.plot(orth=True)
plt.title("Impulse Response for Wu-Xia Shadow Rate (EU)")
plt.show()

def calculate_cumulative_irf(irf_object, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_object.orth_irfs[:n_periods]
    response_names = irf_object.model.names

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            response_values = irf_matrix[:, j, i]
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(response_values))

    return cumulative_irf

cumulative_irf_your_shadow = calculate_cumulative_irf(irf_your_shadow, n_periods=10)
cumulative_irf_wu_xia_shadow = calculate_cumulative_irf(irf_wu_xia_shadow, n_periods=10)

comparison_df = pd.DataFrame({
    "Proposed Shadow Rate": cumulative_irf_your_shadow,
    "Wu-Xia Shadow Rate": cumulative_irf_wu_xia_shadow
}).T

comparison_df.loc['Difference'] = (
    comparison_df.loc['Proposed Shadow Rate'] - comparison_df.loc['Wu-Xia Shadow Rate']
)

print("Cumulative Impulse Responses Comparison for EU:")
print(comparison_df)

output_file = 'cumulative_irf_comparison_eu.csv'
comparison_df.to_csv(output_file)
print(f"Comparison data saved as '{output_file}' in the current working directory.")

comparison_df.loc["Proposed Shadow Rate"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="Proposed Shadow Rate")
comparison_df.loc["Wu-Xia Shadow Rate"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="Wu-Xia Shadow Rate", color="orange")
plt.title("Cumulative Impulse Responses Comparison (EU)")
plt.xlabel("Response → Impulse")
plt.ylabel("Cumulative IRF")
plt.legend()
plt.tight_layout()
plt.show()

# !pip install statsmodels

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR

file_path = '/content/new entry eu.xlsx'
xls = pd.ExcelFile(file_path)

shadow_eu = pd.read_excel(xls, sheet_name='My shadow rates EU', parse_dates=['Date'])
inflation_eu = pd.read_excel(xls, sheet_name='Inflation EU', parse_dates=['Date'])
gdp_eu = pd.read_excel(xls, sheet_name='Real GDP EU', parse_dates=['Date'])

shadow_eu.set_index('Date', inplace=True)
inflation_eu.set_index('Date', inplace=True)
gdp_eu.set_index('Date', inplace=True)

data_eu = pd.concat([shadow_eu, inflation_eu, gdp_eu], axis=1).dropna()

print("\nMerged Data Columns (EU):")
print(data_eu.columns)

data_eu['INF EU'] = data_eu['INF EU'].pct_change() * 100
data_eu['GDP EU'] = data_eu['GDP EU'].pct_change() * 100

data_eu = data_eu.dropna()

print("\nAfter transformations (first few rows):")
print(data_eu.head())

def prepare_var_data(df):
    standardized_data = (df - df.mean()) / df.std()
    return standardized_data

var_data_eu = prepare_var_data(data_eu)

model_eu = VAR(var_data_eu)
lag_order = 2
results_eu = model_eu.fit(lag_order)

print("\nVAR Model Summary (EU):")
print(results_eu.summary())

n_periods = 20
irf_eu = results_eu.irf(n_periods)

print("\nImpulse Response Functions (EU system):")
irf_eu.plot(orth=True)
plt.suptitle('Impulse Response Functions - Final Shadow Rate System (EU)')
plt.show()

def calculate_cumulative_irf(irf_obj, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_obj.orth_irfs[:n_periods]
    response_names = irf_obj.model.names

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(irf_matrix[:, j, i]))

    return cumulative_irf

cumulative_irf_eu = calculate_cumulative_irf(irf_eu)
cumulative_irf_eu_df = pd.DataFrame(cumulative_irf_eu, index=['Cumulative IRF'])

print("\nCumulative IRF Results (EU):")
print(cumulative_irf_eu_df.T)

cumulative_irf_eu_df.T.to_excel('cumulative_irf_final_shadow_eu.xlsx')
print("\nCumulative IRF saved to 'cumulative_irf_final_shadow_eu.xlsx'.")
# Out:
# Index(['Wu-Xia Shadow Rate EU', 'Proposed Shadow Rate', 'Ind Prod EU',
#        'CPI EU', 'Unemployment EU', 'Bond Yield EU 3M', 'Bond Yield EU 10Y'],
#       dtype='object')
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Aug, 2025
# Time:                     13:25:17
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   0.171592
# Nobs:                     99.0000    HQIC:                 -0.390273
# Log likelihood:          -487.681    FPE:                   0.462979
# AIC:                    -0.772088    Det(Omega_mle):        0.326894
# --------------------------------------------------------------------
# Results for equation Factor1
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                           0.033430         0.147794            0.226           0.821
# L1.Factor1                      0.468593         0.109086            4.296           0.000
# L1.Factor2                     -0.045357         0.143190           -0.317           0.751
# L1.Factor3                      0.208049         0.158790            1.310           0.190
# L1.Proposed Shadow Rate         0.571828         0.353412            1.618           0.106
# L2.Factor1                      0.048860         0.118847            0.411           0.681
# L2.Factor2                     -0.063290         0.144293           -0.439           0.661
# L2.Factor3                      0.019619         0.151334            0.130           0.897
# L2.Proposed Shadow Rate        -0.084041         0.352191           -0.239           0.811
# ==========================================================================================
#
# Results for equation Factor2
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.031388         0.115302           -0.272           0.785
# L1.Factor1                      0.100336         0.085104            1.179           0.238
# L1.Factor2                      0.077430         0.111710            0.693           0.488
# L1.Factor3                      0.061555         0.123881            0.497           0.619
# L1.Proposed Shadow Rate        -0.332321         0.275715           -1.205           0.228
# L2.Factor1                     -0.117373         0.092719           -1.266           0.206
# L2.Factor2                     -0.038126         0.112570           -0.339           0.735
# L2.Factor3                     -0.005285         0.118063           -0.045           0.964
# L2.Proposed Shadow Rate         0.104567         0.274763            0.381           0.704
# ==========================================================================================
#
# Results for equation Factor3
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                           0.030340         0.105420            0.288           0.773
# L1.Factor1                      0.179578         0.077810            2.308           0.021
# L1.Factor2                      0.242688         0.102136            2.376           0.017
# L1.Factor3                     -0.162428         0.113264           -1.434           0.152
# L1.Proposed Shadow Rate         0.078258         0.252086            0.310           0.756
# L2.Factor1                      0.018527         0.084773            0.219           0.827
# L2.Factor2                      0.128047         0.102923            1.244           0.213
# L2.Factor3                      0.077287         0.107945            0.716           0.474
# L2.Proposed Shadow Rate         0.295376         0.251215            1.176           0.240
# ==========================================================================================
#
# Results for equation Proposed Shadow Rate
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.128075         0.051247           -2.499           0.012
# L1.Factor1                     -0.097838         0.037825           -2.587           0.010
# L1.Factor2                      0.004545         0.049650            0.092           0.927
# L1.Factor3                     -0.017988         0.055059           -0.327           0.744
# L1.Proposed Shadow Rate        -0.149864         0.122543           -1.223           0.221
# L2.Factor1                     -0.027613         0.041209           -0.670           0.503
# L2.Factor2                     -0.044339         0.050032           -0.886           0.376
# L2.Factor3                     -0.054303         0.052474           -1.035           0.301
# L2.Proposed Shadow Rate        -0.129388         0.122120           -1.060           0.289
# ==========================================================================================
#
# Correlation matrix of residuals
#                          Factor1   Factor2   Factor3  Proposed Shadow Rate
# Factor1                 1.000000 -0.041376 -0.137138             -0.175435
# Factor2                -0.041376  1.000000 -0.025448              0.329383
# Factor3                -0.137138 -0.025448  1.000000             -0.276445
# Proposed Shadow Rate   -0.175435  0.329383 -0.276445              1.000000
#
#
#
#
# Correlation matrix of residuals
#                        Factor1   Factor2   Factor3  Proposed Shadow Rate
# Factor1               1.000000 -0.041376 -0.137138             -0.175435
# Factor2              -0.041376  1.000000 -0.025448              0.329383
# Factor3              -0.137138 -0.025448  1.000000             -0.276445
# Proposed Shadow Rate -0.175435  0.329383 -0.276445              1.000000
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Aug, 2025
# Time:                     13:25:17
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   0.289643
# Nobs:                     99.0000    HQIC:                 -0.272222
# Log likelihood:          -493.525    FPE:                   0.520991
# AIC:                    -0.654037    Det(Omega_mle):        0.367854
# --------------------------------------------------------------------
# Results for equation Factor1
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                           -0.009504         0.125345           -0.076           0.940
# L1.Factor1                       0.321091         0.114215            2.811           0.005
# L1.Factor2                       0.361587         0.113091            3.197           0.001
# L1.Factor3                      -0.117652         0.145640           -0.808           0.419
# L1.Wu-Xia Shadow Rate EU        -0.104412         0.277239           -0.377           0.706
# L2.Factor1                       0.153618         0.114303            1.344           0.179
# L2.Factor2                       0.189961         0.125546            1.513           0.130
# L2.Factor3                       0.008526         0.134046            0.064           0.949
# L2.Wu-Xia Shadow Rate EU         0.423118         0.276014            1.533           0.125
# ===========================================================================================
#
# Results for equation Factor2
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                           -0.007235         0.118888           -0.061           0.951
# L1.Factor1                       0.211569         0.108331            1.953           0.051
# L1.Factor2                      -0.088121         0.107266           -0.822           0.411
# L1.Factor3                       0.043256         0.138138            0.313           0.754
# L1.Wu-Xia Shadow Rate EU         0.064802         0.262958            0.246           0.805
# L2.Factor1                      -0.060394         0.108415           -0.557           0.577
# L2.Factor2                      -0.169253         0.119079           -1.421           0.155
# L2.Factor3                      -0.104441         0.127141           -0.821           0.411
# L2.Wu-Xia Shadow Rate EU         0.027187         0.261796            0.104           0.917
# ===========================================================================================
#
# Results for equation Factor3
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                            0.007276         0.097147            0.075           0.940
# L1.Factor1                       0.156402         0.088521            1.767           0.077
# L1.Factor2                       0.266783         0.087650            3.044           0.002
# L1.Factor3                       0.112238         0.112877            0.994           0.320
# L1.Wu-Xia Shadow Rate EU         0.105500         0.214871            0.491           0.623
# L2.Factor1                      -0.092956         0.088589           -1.049           0.294
# L2.Factor2                       0.102819         0.097303            1.057           0.291
# L2.Factor3                       0.022272         0.103890            0.214           0.830
# L2.Wu-Xia Shadow Rate EU         0.088949         0.213921            0.416           0.678
# ===========================================================================================
#
# Results for equation Wu-Xia Shadow Rate EU
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                           -0.057067         0.057435           -0.994           0.320
# L1.Factor1                      -0.097167         0.052335           -1.857           0.063
# L1.Factor2                      -0.090057         0.051820           -1.738           0.082
# L1.Factor3                       0.079720         0.066735            1.195           0.232
# L1.Wu-Xia Shadow Rate EU        -0.148232         0.127035           -1.167           0.243
# L2.Factor1                      -0.047324         0.052376           -0.904           0.366
# L2.Factor2                      -0.048358         0.057527           -0.841           0.401
# L2.Factor3                       0.070425         0.061422            1.147           0.252
# L2.Wu-Xia Shadow Rate EU        -0.015656         0.126474           -0.124           0.901
# ===========================================================================================
#
# Correlation matrix of residuals
#                           Factor1   Factor2   Factor3  Wu-Xia Shadow Rate EU
# Factor1                  1.000000 -0.024445 -0.190100              -0.432352
# Factor2                 -0.024445  1.000000  0.009797              -0.248694
# Factor3                 -0.190100  0.009797  1.000000               0.390664
# Wu-Xia Shadow Rate EU   -0.432352 -0.248694  0.390664               1.000000
#
#
#
#
# Correlation matrix of residuals
#                         Factor1   Factor2   Factor3  Wu-Xia Shadow Rate EU
# Factor1                1.000000 -0.024445 -0.190100              -0.432352
# Factor2               -0.024445  1.000000  0.009797              -0.248694
# Factor3               -0.190100  0.009797  1.000000               0.390664
# Wu-Xia Shadow Rate EU -0.432352 -0.248694  0.390664               1.000000
# Impulse Response for the proposed Shadow Rate (EU):
# Impulse Response for Wu-Xia Shadow Rate (EU):
# Cumulative Impulse Responses Comparison for EU:
#                       Factor1 → Factor1  Factor2 → Factor1  Factor3 → Factor1  \
# Proposed Shadow Rate           2.583873           0.302301           0.502726
# Wu-Xia Shadow Rate             2.260438           0.331092           0.381068
# Difference                     0.323435          -0.028792           0.121658
#
#                       Proposed Shadow Rate → Factor1  Factor1 → Factor2  \
# Proposed Shadow Rate                        0.331053           0.074353
# Wu-Xia Shadow Rate                               NaN           0.767989
# Difference                                       NaN          -0.693636
#
#                       Factor2 → Factor2  Factor3 → Factor2  \
# Proposed Shadow Rate           1.121441           0.466458
# Wu-Xia Shadow Rate             1.411000           0.525217
# Difference                    -0.289559          -0.058759
#
#                       Proposed Shadow Rate → Factor2  Factor1 → Factor3  \
# Proposed Shadow Rate                        0.249328           0.214912
# Wu-Xia Shadow Rate                               NaN           0.229600
# Difference                                       NaN          -0.014688
#
#                       Factor2 → Factor3  ...  Factor2 → Proposed Shadow Rate  \
# Proposed Shadow Rate           0.134378  ...                        0.249901
# Wu-Xia Shadow Rate             0.190692  ...                             NaN
# Difference                    -0.056314  ...                             NaN
#
#                       Factor3 → Proposed Shadow Rate  \
# Proposed Shadow Rate                        0.195841
# Wu-Xia Shadow Rate                               NaN
# Difference                                       NaN
#
#                       Proposed Shadow Rate → Proposed Shadow Rate  \
# Proposed Shadow Rate                                     0.566157
# Wu-Xia Shadow Rate                                            NaN
# Difference                                                    NaN
#
#                       Wu-Xia Shadow Rate EU → Factor1  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.523872
# Difference                                        NaN
#
#                       Wu-Xia Shadow Rate EU → Factor2  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.310315
# Difference                                        NaN
#
#                       Wu-Xia Shadow Rate EU → Factor3  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.321204
# Difference                                        NaN
#
#                       Factor1 → Wu-Xia Shadow Rate EU  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.344679
# Difference                                        NaN
#
#                       Factor2 → Wu-Xia Shadow Rate EU  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.081222
# Difference                                        NaN
#
#                       Factor3 → Wu-Xia Shadow Rate EU  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.133068
# Difference                                        NaN
#
#                       Wu-Xia Shadow Rate EU → Wu-Xia Shadow Rate EU
# Proposed Shadow Rate                                            NaN
# Wu-Xia Shadow Rate                                         0.554688
# Difference                                                      NaN
#
# [3 rows x 23 columns]
# Comparison data saved as 'cumulative_irf_comparison_eu.csv' in the current working directory.
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.1)
# Requirement already satisfied: numpy<2,>=1.18 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.0->statsmodels) (1.17.0)
#
# Merged Data Columns (EU):
# Index(['Final Shadow Rate', 'INF EU', 'GDP EU'], dtype='object')
#
# After transformations (first few rows):
#             Final Shadow Rate    INF EU    GDP EU
# Date
# 2009-01-01           5.420489 -1.401869 -3.081868
# 2009-04-01           6.036941  1.135236 -0.035236
# 2009-07-01           5.819896 -0.403226  0.392424
# 2009-10-01           5.125132  0.579932  0.492971
# 2010-01-01           4.225509 -0.380766  0.367195
#
# VAR Model Summary (EU):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Aug, 2025
# Time:                     13:25:30
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -1.47546
# Nobs:                     55.0000    HQIC:                  -1.94551
# Log likelihood:          -151.473    FPE:                   0.106700
# AIC:                     -2.24189    Det(Omega_mle):       0.0744867
# --------------------------------------------------------------------
# Results for equation Final Shadow Rate
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.064991         0.050050           -1.299           0.194
# L1.Final Shadow Rate         0.085989         0.284267            0.302           0.762
# L1.INF EU                    0.138163         0.053942            2.561           0.010
# L1.GDP EU                   -0.109992         0.060185           -1.828           0.068
# L2.Final Shadow Rate         0.798282         0.274785            2.905           0.004
# L2.INF EU                    0.082439         0.053968            1.528           0.127
# L2.GDP EU                   -0.018877         0.050511           -0.374           0.709
# =======================================================================================
#
# Results for equation INF EU
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.053970         0.118751            0.454           0.649
# L1.Final Shadow Rate         0.264532         0.674464            0.392           0.695
# L1.INF EU                   -0.196649         0.127984           -1.537           0.124
# L1.GDP EU                   -0.024801         0.142796           -0.174           0.862
# L2.Final Shadow Rate        -0.309390         0.651967           -0.475           0.635
# L2.INF EU                    0.535025         0.128048            4.178           0.000
# L2.GDP EU                    0.069218         0.119845            0.578           0.564
# =======================================================================================
#
# Results for equation GDP EU
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.086947         0.137288            0.633           0.527
# L1.Final Shadow Rate         1.014296         0.779748            1.301           0.193
# L1.INF EU                    0.068934         0.147963            0.466           0.641
# L1.GDP EU                   -0.205298         0.165087           -1.244           0.214
# L2.Final Shadow Rate        -0.998081         0.753740           -1.324           0.185
# L2.INF EU                   -0.019860         0.148036           -0.134           0.893
# L2.GDP EU                   -0.159057         0.138553           -1.148           0.251
# =======================================================================================
#
# Correlation matrix of residuals
#                      Final Shadow Rate    INF EU    GDP EU
# Final Shadow Rate             1.000000  0.002252 -0.304711
# INF EU                        0.002252  1.000000  0.061539
# GDP EU                       -0.304711  0.061539  1.000000
#
#
#
#
# Impulse Response Functions (EU system):
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# Cumulative IRF Results (EU):
#                                        Cumulative IRF
# Final Shadow Rate → Final Shadow Rate        1.549315
# INF EU → Final Shadow Rate                   1.449286
# GDP EU → Final Shadow Rate                   1.792274
# Final Shadow Rate → INF EU                   0.893226
# INF EU → INF EU                              3.071532
# GDP EU → INF EU                              0.529283
# Final Shadow Rate → GDP EU                   0.319020
# INF EU → GDP EU                              0.177207
# GDP EU → GDP EU                              1.610145
#
# Cumulative IRF saved to 'cumulative_irf_final_shadow_eu.xlsx'.
