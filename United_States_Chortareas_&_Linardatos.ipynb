# %% [markdown]
# <a href="https://colab.research.google.com/github/Konstantinosil/Chortareas-Linardatos/blob/main/United_States_Chortareas_%26_Linardatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install filterpy==1.4.5 scikit-learn==1.4.2 statsmodels==0.14.1

import numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path; from scipy.optimize import minimize
from filterpy.kalman import KalmanFilter
from sklearn.decomposition import PCA; from sklearn.preprocessing import StandardScaler
from statsmodels.regression.linear_model import OLS; from statsmodels.tools.tools import add_constant
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox, het_arch
from statsmodels.tsa.ar_model import AutoReg
from IPython.display import display

SEED = 42
rng  = np.random.default_rng(SEED);  np.random.seed(SEED)

DATA = Path("/content/data shadow new us.xlsx")
xls  = pd.ExcelFile(DATA)

def _prep(sheet, cols):
    df = pd.read_excel(xls, sheet, header=1)
    df.columns = cols
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
    return df.dropna(subset=["Date"]).set_index("Date")

ser = {
    "SR" : _prep("Shadow Rates US", ["Date","SR US"]),
    "INF": _prep("Inflation Data US", ["Date","INF US"]),
    "UN" : _prep("Unemployment Data US", ["Date","UNEM US"]),
    "CDS": _prep("Sovereign CDS Spreads US", ["Date","CDS US"]),
    "GDP": _prep("Real GDP US", ["Date","GDP US"]),
    "EX" : _prep("Exchange Rates US", ["Date","EX US"]),
    "3M" : _prep("3M",  ["Date","3M US"]),
    "6M" : _prep("6M",  ["Date","6M US"]),
    "1Y" : _prep("1Y",  ["Date","1Y US"]),
    "2Y" : _prep("2Y",  ["Date","2Y US"]),
    "5Y" : _prep("5Y",  ["Date","5Y US"]),
    "7Y" : _prep("7Y",  ["Date","7Y US"]),
    "10Y": _prep("10Y", ["Date","10Y US"]),
    "30Y": _prep("30Y", ["Date","30Y US"]),
}

df = pd.concat(ser.values(), axis=1).interpolate("linear")
macro = ["INF US","UNEM US","EX US","CDS US","GDP US"]
ylds  = ["3M US","6M US","1Y US","2Y US","5Y US","7Y US","10Y US","30Y US"]
df    = df.dropna(subset=["SR US"] + macro + ylds)

y_df, m_df = df[ylds].copy(), df[macro].copy()

var_list = ylds + macro
tbl_station, tbl_ac, tbl_arch = [], [], []

for v in var_list:
    s0 = df[v].dropna()
    adf0 = adfuller(s0, autolag='AIC'); stat0, p0 = adf0[0], adf0[1]

    if p0 < .05:
        tbl_station.append([v, stat0, p0, 'Stat']);  s_final = s0
    else:
        s1 = s0.diff().dropna()
        adf1 = adfuller(s1, autolag='AIC')
        tbl_station += [[f'{v}(orig)',stat0,p0,'NOT stat'],
                        [f'{v}(Δ1)',adf1[0],adf1[1],
                         'Stat' if adf1[1]<.05 else 'NOT']]
        s_final = s1

    lb_p   = acorr_ljungbox(s_final, lags=[10], return_df=True)['lb_pvalue'].iloc[0]
    arch_p = het_arch(s_final, maxlag=10)[1]
    tbl_ac.append([v, lb_p,   'Sig' if lb_p<.05  else 'OK'])
    tbl_arch.append([v, arch_p,'Sig' if arch_p<.05 else 'OK'])

print("\n=== ADF ===");   display(pd.DataFrame(tbl_station, columns=['Var','ADF','p','Res']))
print("\n=== LB  ===");  display(pd.DataFrame(tbl_ac,      columns=['Var','p','AC?']))
print("\n=== ARCH ==="); display(pd.DataFrame(tbl_arch,    columns=['Var','p','ARCH?']))

if y_df.abs().max().max() > 20: y_df /= 100
low, upp = y_df.mean()-3*y_df.std(), y_df.mean()+3*y_df.std()
y_df = y_df.clip(lower=low, upper=upp, axis=1)
m_z  = pd.DataFrame(StandardScaler().fit_transform(m_df),
                    index=m_df.index, columns=m_df.columns)

def _beta(y,z):
    X = add_constant(z); return {c: OLS(y[c],X).fit().params.values for c in y}

def _pca(y): return PCA(1,random_state=SEED).fit_transform(y).ravel()

def _sim(n,r0,z,β,ψ,lb=-2):
    κ,σ,λ,μ,s,θ0,θ1,θ2 = ψ; z0,z1 = 240,1992
    S=np.empty(n); S[0]=r0
    for t in range(1,n):
        θ = θ0 if t<z0 else (θ1 if t<=z1 else θ2)
        S[t]=S[t-1]+κ*(θ-S[t-1])+σ*rng.normal()
        if rng.random()<λ: S[t]+=rng.normal(μ,s)
        if S[t]<lb: S[t]=lb+0.3*(S[t]-lb)
        Xt=z.iloc[t].values
        S[t]+=0.5*np.mean([Xt@β[m][1:] for m in β])
    return S

def _kalman(x):
    kf=KalmanFilter(dim_x=1,dim_z=1)
    kf.x=[[x[0]]]; kf.F=kf.H=np.eye(1); kf.P*=100; kf.R[:]=1; kf.Q[:]=0.01
    out=[]
    for v in x: kf.predict(); kf.update([[v]]); out.append(kf.x[0,0])
    return np.array(out)

β   = _beta(y_df,m_z); pca = _pca(y_df)
print("\n=== β̂m (macro loading per maturity) ===")
for m, coef in β.items():
    print(f"{m:>5}: {coef[1]:+.4f}")
pca = _pca(y_df)
θ0, θ1, θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()
x0  = [0.15,0.015,0.005,0.10,0.05, θ0,θ1,θ2]
bnd = [(1e-4,1),(1e-4,0.05),(0,0.1),(-.5,.5),(1e-4,0.2),(-5,5),(-5,5),(-5,5)]
obj = lambda p: ((_sim(len(pca),pca[0],m_z,β,p)-pca)**2).sum()
ψhat= minimize(obj,x0,bounds=bnd,method='L-BFGS-B',
               options={'maxiter':500}).x

S     = _sim(len(pca),pca[0],m_z,β,ψhat)
S_sm  = _kalman(S)
final = pd.Series(0.7*pca+0.3*S_sm,index=df.index,name='Final SR')

print("\nψ̂:",np.round(ψhat,4))
display(final.head())

ws   = np.arange(0.50, 0.95, 0.05)
rmse = []

for w in ws:
    shadow = w*pca + (1-w)*S_sm
    errs = []
    for m in ylds:
        y_hat = OLS(y_df[m], add_constant(shadow)).fit().fittedvalues
        errs.append(((y_df[m]-y_hat)**2).mean())
    rmse.append(np.sqrt(np.mean(errs))*1e4)

grid = pd.DataFrame({"w": ws, "RMSE_bp": rmse})
print(grid.round(2))

grid.plot(x="w", y="RMSE_bp", marker="o", figsize=(4,3.5))
plt.ylabel("mean cross-section RMSE (bp)"); plt.tight_layout(); plt.show()


plt.figure(figsize=(5,3.5))
plt.bar(range(1,9), PCA().fit(y_df).explained_variance_ratio_)
plt.xlabel('PC'); plt.ylabel('Explained var share')
plt.title('Scree – US Yield Curve'); plt.tight_layout(); plt.show()

plt.figure(figsize=(11,5))
plt.plot(df.index,final,label='Final SR')
plt.plot(df.index,pca,'--',label='PCA'); plt.grid(); plt.legend()
plt.title('US shadow-rate'); plt.show()

start,end='2009-01-01','2022-08-01'; alpha=0.05
ewma = final.ewm(alpha=alpha,adjust=False).mean().loc[start:end]
wu   = df['SR US'].loc[start:end]

plt.figure(figsize=(11,5))
plt.plot(final.resample('M').mean().loc[start:end],lw=2,label='Final (monthly)')
plt.plot(wu.resample('M').last(),'--',label='Wu-Xia'); plt.grid(); plt.legend()
plt.ylabel('%'); plt.title('Final vs Wu-Xia (monthly)'); plt.show()

plt.figure(figsize=(11,5))
plt.plot(ewma,lw=2,label=f'Final EWMA (α={alpha})')
plt.plot(wu,'--',label='Wu-Xia'); plt.grid(); plt.legend()
plt.ylabel('%'); plt.title('Final EWMA vs Wu-Xia (daily)'); plt.show()

fit_tbl=[]
for m in ylds:
    rmse_f = np.sqrt(((OLS(y_df[m], add_constant(final)).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    rmse_w = np.sqrt(((OLS(y_df[m], add_constant(df['SR US'])).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    fit_tbl.append([m, rmse_f, rmse_w])

fit_df = pd.DataFrame(fit_tbl, columns=['Maturity','RMSE_final','RMSE_WX'])
print("\n=== In-sample cross-section RMSE (bp) ==="); display(fit_df)

TEST_START = '2023-01-01'
train      = final.loc[:TEST_START]
test_idx   = final.loc[TEST_START:].index
n_train    = len(train)

oos_len   = len(test_idx)

ar1 = AutoReg(train, lags=1, old_names=False).fit()

pred_path = ar1.forecast(steps=oos_len)
pred_path.index = test_idx

fc_df = pd.DataFrame({f'h{h}': pred_path.shift(h-1)
                      for h in range(1, 13)},
                     index=test_idx)

oos_tbl=[]
for m in ylds:
    a,b = OLS(y_df[m].loc[:TEST_START], add_constant(train)).fit().params
    act = y_df[m].loc[TEST_START:]
    for h in range(1,13):
        rmse = np.sqrt(((a + b*fc_df[f'h{h}'] - act)**2).mean())*1e4
        oos_tbl.append([m, h, rmse])

oos_df = (pd.DataFrame(oos_tbl, columns=['Maturity','h','RMSE_bp'])
            .pivot(index='Maturity', columns='h', values='RMSE_bp')
            .reindex(ylds))

print("\n=== OOS RMSE (bp) – forecast horizon h = 1…12 months ===")
display(oos_df.round(2))

OUT = Path("/content/shadow_rate_us.csv")
final.to_csv(OUT, index_label="Date")
final.to_excel("/content/shadow_rate_us.xlsx", sheet_name="US SR")

print(f"\n✓ Shadow-rate series written to:  {OUT.resolve()}")
print(f"  Rows written: {len(final):,}")
# Out:
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
# === ADF ===
# /tmp/ipython-input-701622452.py:67: FutureWarning: the 'maxlag' keyword is deprecated, use 'nlags' instead.
#   arch_p = het_arch(s_final, maxlag=10)[1]
#               Var        ADF             p       Res
# 0     3M US(orig)  -0.398681  9.103188e-01  NOT stat
# 1       3M US(Δ1)  -8.857927  1.510127e-14      Stat
# 2     6M US(orig)  -0.472292  8.973110e-01  NOT stat
# 3       6M US(Δ1)  -8.195282  7.478215e-13      Stat
# 4     1Y US(orig)  -0.464472  8.987651e-01  NOT stat
# 5       1Y US(Δ1)  -8.468604  1.498797e-13      Stat
# 6     2Y US(orig)  -0.402451  9.096887e-01  NOT stat
# 7       2Y US(Δ1) -12.596081  1.777623e-23      Stat
# 8     5Y US(orig)  -1.100372  7.149237e-01  NOT stat
# 9       5Y US(Δ1) -13.232071  9.540122e-25      Stat
# 10    7Y US(orig)  -1.444297  5.608653e-01  NOT stat
# 11      7Y US(Δ1) -13.202779  1.085936e-24      Stat
# 12   10Y US(orig)  -1.711805  4.250408e-01  NOT stat
# 13     10Y US(Δ1) -20.146894  0.000000e+00      Stat
# 14   30Y US(orig)  -1.924887  3.204454e-01  NOT stat
# 15     30Y US(Δ1) -20.415426  0.000000e+00      Stat
# 16   INF US(orig)   1.440177  9.972892e-01  NOT stat
# 17     INF US(Δ1)  -6.666407  4.705562e-09      Stat
# 18  UNEM US(orig)  -2.681729  7.725359e-02  NOT stat
# 19    UNEM US(Δ1)  -8.882952  1.302985e-14      Stat
# 20    EX US(orig)  -1.960269  3.042609e-01  NOT stat
# 21      EX US(Δ1) -64.801951  0.000000e+00      Stat
# 22         CDS US  -3.383743  1.152573e-02      Stat
# 23   GDP US(orig)  -0.531124  8.857984e-01  NOT stat
# 24     GDP US(Δ1)  -6.468197  1.388190e-08      Stat
# === LB  ===
#         Var              p  AC?
# 0     3M US  3.387629e-115  Sig
# 1     6M US   8.413389e-34  Sig
# 2     1Y US   2.930038e-07  Sig
# 3     2Y US   6.813290e-04  Sig
# 4     5Y US   2.277385e-04  Sig
# 5     7Y US   1.120672e-03  Sig
# 6    10Y US   5.582003e-04  Sig
# 7    30Y US   1.477858e-03  Sig
# 8    INF US   0.000000e+00  Sig
# 9   UNEM US   0.000000e+00  Sig
# 10    EX US   6.499369e-01   OK
# 11   CDS US   0.000000e+00  Sig
# 12   GDP US   0.000000e+00  Sig
# === ARCH ===
#         Var              p ARCH?
# 0     3M US   0.000000e+00   Sig
# 1     6M US  7.722107e-169   Sig
# 2     1Y US  2.442776e-149   Sig
# 3     2Y US  9.638482e-150   Sig
# 4     5Y US   1.816709e-88   Sig
# 5     7Y US   2.844670e-60   Sig
# 6    10Y US   3.924788e-62   Sig
# 7    30Y US  3.299369e-107   Sig
# 8    INF US   0.000000e+00   Sig
# 9   UNEM US   0.000000e+00   Sig
# 10    EX US   7.756469e-80   Sig
# 11   CDS US   0.000000e+00   Sig
# 12   GDP US   0.000000e+00   Sig
# === β̂m (macro loading per maturity) ===
# 3M US: +1.6821
# 6M US: +1.9353
# 1Y US: +1.9689
# 2Y US: +1.9967
# 5Y US: +2.0857
# 7Y US: +2.0747
# 10Y US: +2.0544
# 30Y US: +1.8822
#
# ψ̂: [ 0.15    0.015   0.005   0.1     0.05    2.0933 -0.9004 -0.0035]
# Date
# 2008-07-22    2.739082
# 2008-07-23    2.746063
# 2008-07-24    2.538533
# 2008-07-25    2.647290
# 2008-07-28    2.488559
# Name: Final SR, dtype: float64
#       w  RMSE_bp
# 0  0.50  5212.25
# 1  0.55  5062.46
# 2  0.60  4925.61
# 3  0.65  4802.83
# 4  0.70  4695.10
# 5  0.75  4603.27
# 6  0.80  4527.94
# 7  0.85  4469.52
# 8  0.90  4428.13
# /tmp/ipython-input-701622452.py:157: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.plot(final.resample('M').mean().loc[start:end],lw=2,label='Final (monthly)')
# /tmp/ipython-input-701622452.py:158: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.plot(wu.resample('M').last(),'--',label='Wu-Xia'); plt.grid(); plt.legend()
# === In-sample cross-section RMSE (bp) ===
#   Maturity   RMSE_final      RMSE_WX
# 0    3M US  3926.297712  5282.822912
# 1    6M US  3307.626133  5003.218140
# 2    1Y US  2812.097954  4575.818339
# 3    2Y US  2482.328207  4498.701913
# 4    5Y US  4029.601718  6034.649004
# 5    7Y US  5118.919540  6793.441139
# 6   10Y US  6178.413038  7495.215911
# 7   30Y US  7437.205794  8141.299311
# === OOS RMSE (bp) – forecast horizon h = 1…12 months ===
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/deterministic.py:307: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# h               1         2         3         4         5         6   \
# Maturity
# 3M US     13127.34  13102.70  13078.06  13053.40  13028.86  13003.75
# 6M US     18485.36  18445.41  18405.58  18365.86  18326.25  18286.64
# 1Y US     22976.23  22930.45  22884.75  22839.14  22793.60  22748.14
# 2Y US     24731.22  24684.72  24638.27  24591.88  24545.42  24499.28
# 5Y US     19848.86  19811.48  19774.05  19736.56  19698.60  19660.97
# 7Y US     15341.00  15309.94  15278.79  15247.53  15215.68  15184.05
# 10Y US    10452.58  10427.82  10402.92  10377.85  10352.06  10326.45
# 30Y US     3007.39   3005.86   3004.39   3002.94   3001.20   2999.30
#
# h               7         8         9         10        11        12
# Maturity
# 3M US     12978.82  12953.72  12928.62  12903.71  12879.61  12855.61
# 6M US     18247.21  18207.77  18168.36  18129.12  18090.25  18051.49
# 1Y US     22702.77  22657.48  22612.28  22567.16  22522.11  22477.16
# 2Y US     24452.52  24405.62  24359.00  24312.27  24265.23  24218.71
# 5Y US     19621.95  19582.73  19544.01  19504.86  19464.60  19425.01
# 7Y US     15150.98  15117.66  15084.99  15051.82  15017.35  14983.64
# 10Y US    10299.35  10272.04  10245.60  10218.44  10189.95  10162.23
# 30Y US     2996.08   2992.80   2990.78   2987.88   2982.89   2979.09
# ✓ Shadow-rate series written to:  /content/shadow_rate_us.csv
#   Rows written: 4,375

# %%
# !pip -q install fredapi

import warnings, zipfile, numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path
from statsmodels.tsa.api import VAR
from fredapi import Fred
from tqdm.notebook import trange
warnings.filterwarnings("ignore", category=FutureWarning)

FRED_KEY  = "7d89f5a2b8b4d60cae7b98f2ba830f73"
MY_XLSX   = "/content/gia cascaldi & Galvao analisi.xlsx"
ZIP_LOCAL = "/content/Replication codes - Cascaldi-Garcia and Galvao JMCB.zip"

START_M, END_M = "2008-01", "2015-12"
p       = 3
H_IRF   = 36
BOOT    = 500
BLOCK   = 3
ROLL_H  = 1
rng     = np.random.default_rng(0)

WORK_DIR = Path("replication_cgg_mo"); WORK_DIR.mkdir(exist_ok=True)
with zipfile.ZipFile(ZIP_LOCAL, "r") as z: z.extractall(WORK_DIR)
MAT_PATH = next(WORK_DIR.glob("*/Database_CG-G.mat"))

import scipy.io as sio
mat  = sio.loadmat(MAT_PATH, squeeze_me=True, struct_as_record=False)
qidx = pd.date_range("1975-03-31", periods=mat["RGDP"].shape[0], freq="Q-DEC")

fred = Fred(api_key=FRED_KEY)
wx_mo = (fred.get_series("WSHOSHO")
           .resample("M").mean()
           .rename("SHADOW"))

sr_daily = (pd.read_excel(MY_XLSX)
              .assign(Date=lambda d: pd.to_datetime(d["Date"], errors="coerce"))
              .dropna(subset=["Date"])
              .set_index("Date")["Generated Shadow Rate"]
              .astype(float))

sr_mo = sr_daily.resample("M").mean()
shadow_my_mo = wx_mo.copy()
shadow_my_mo.loc[sr_mo.index] = sr_mo
shadow_my_mo.name = "SHADOW"

vars_macro = ["LTFP2","RPCE","EBPm","RVOL1m","JLN1m",
              "RGDP","RINV","RHOURS","RDEF","RSP500"]

df_q = pd.DataFrame({v: mat[v].ravel().astype(float) for v in vars_macro},
                    index=qidx)

macro_mo = (df_q
            .resample("M").last()
            .interpolate(method="linear"))

df_wx = pd.concat([macro_mo, wx_mo], axis=1).loc[START_M:END_M].dropna()
df_my = pd.concat([macro_mo, shadow_my_mo], axis=1).loc[START_M:END_M].dropna()

for df in (df_wx, df_my):
    df[:] = (df - df.mean()) / df.std()

print(f"Months in sample: {len(df_wx)}   ({df_wx.index[0]} → {df_wx.index[-1]})")

res_wx, res_my = VAR(df_wx).fit(p), VAR(df_my).fit(p)
print(f"Wu-Xia VAR({p})  T={res_wx.nobs}   |   Our VAR({p})  T={res_my.nobs}")

def girf(res, tgt="RGDP", sh="SHADOW", H=H_IRF):
    Σ = res.sigma_u.to_numpy()
    j, k = res.names.index(tgt), res.names.index(sh)
    ma = res.ma_rep(maxn=H)
    return np.array([ma[h, j, :].dot(Σ[:, k]) / np.sqrt(Σ[k, k])
                     for h in range(H+1)])

def simulate_var_manual(res, u):
    A, c = res.coefs, res.intercept
    k, T, pL = c.size, u.shape[0], A.shape[0]
    y = np.zeros((T+pL, k)); y[:pL] = res.model.endog[-pL:]
    for t in range(pL, T+pL):
        lag = sum(A[i] @ y[t-i-1] for i in range(pL))
        y[t] = c + lag + u[t-pL]
    return y[pL:]

def block_boot_girf(res, draws=BOOT, H=H_IRF, block=BLOCK):
    resid = res.resid.to_numpy(); T = resid.shape[0]
    out = np.empty((draws, H+1))
    for b in trange(draws, desc="boot", leave=False):
        idx = []
        while len(idx) < T:
            s = rng.integers(0, T-block)
            idx.extend(range(s, s+block))
        u_b = resid[np.array(idx[:T])]
        fit = VAR(pd.DataFrame(simulate_var_manual(res, u_b),
                               columns=res.names)).fit(p)
        out[b] = girf(fit, H=H)
    return np.percentile(out, [5,16,84,95], axis=0)

g_wx, g_my  = girf(res_wx), girf(res_my)
band_wx     = block_boot_girf(res_wx)

m = np.arange(H_IRF+1)/12
plt.plot(m, g_wx,  label="Wu-Xia")
plt.plot(m, g_my, "--", label="Our SR")
plt.fill_between(m, band_wx[1], band_wx[2], alpha=.15)
plt.fill_between(m, band_wx[0], band_wx[3], alpha=.07)
plt.axhline(0); plt.xlabel("years"); plt.ylabel("% dev")
plt.title("RGDP GIRF (monthly VAR, 1 σ shadow shock)")
plt.legend(); plt.tight_layout(); plt.show()

rmse_wx, rmse_my = [], []
start_roll = max(p + ROLL_H + BLOCK, df_wx.shape[1] + 1)

for t in trange(start_roll, len(df_wx) - ROLL_H, leave=False):
    mod_wx = VAR(df_wx.iloc[:t]).fit(p)
    mod_my = VAR(df_my.iloc[:t]).fit(p)

    f_wx = mod_wx.forecast(df_wx.values[t-p:t], ROLL_H)[-1,
             mod_wx.names.index("RGDP")]
    f_my = mod_my.forecast(df_my.values[t-p:t], ROLL_H)[-1,
             mod_my.names.index("RGDP")]

    y_obs = df_wx["RGDP"].iloc[t]
    rmse_wx.append((y_obs - f_wx)**2)
    rmse_my.append((y_obs - f_my)**2)

d = np.array(rmse_wx) - np.array(rmse_my)
L = BLOCK; M=len(d)
var_d = L * np.var([d[i::L].mean() for i in range(L)], ddof=1) / M
DM = d.mean() / np.sqrt(var_d)
print(f"\nRolling 1-step DM = {DM:+5.2f}   (|stat|>1.96 ⇒ 5 %)")

import numpy as np, pandas as pd
from statsmodels.tsa.api import VAR
from tqdm.notebook import trange

BLOCK = 3
def hac_var(d, L=BLOCK):
    M = len(d)
    if M == 0: return np.nan
    block_means = np.array([d[i::L].mean() for i in range(L)])
    return L * block_means.var(ddof=1) / M

def rolling_msfe(df_wx, df_my, p, h):
    rmse_wx, rmse_my = [], []
    start_roll = max(p + h + BLOCK, df_wx.shape[1] + 1)

    for t in range(start_roll, len(df_wx) - h):
        mod_wx = VAR(df_wx.iloc[:t]).fit(p)
        mod_my = VAR(df_my.iloc[:t]).fit(p)

        f_wx = mod_wx.forecast(df_wx.values[t-p:t], h)[-1,
                mod_wx.names.index("RGDP")]
        f_my = mod_my.forecast(df_my.values[t-p:t], h)[-1,
                mod_my.names.index("RGDP")]
        y_obs = df_wx["RGDP"].iloc[t+h-1]

        rmse_wx.append((y_obs - f_wx)**2)
        rmse_my.append((y_obs - f_my)**2)

    d = np.array(rmse_wx) - np.array(rmse_my)
    DM = d.mean() / np.sqrt(hac_var(d))
    return DM, len(d)

sel = VAR(df_wx).select_order(maxlags=6)
p_aic, p_bic = sel.aic, sel.bic
print(f"AIC-optimal p = {p_aic}   |   BIC-optimal p = {p_bic}")

horizons = [1, 3, 6, 12]
results = []
for crit, p_sel in [("AIC", p_aic), ("BIC", p_bic)]:
    for h in horizons:
        DM, N = rolling_msfe(df_wx, df_my, p_sel, h)
        results.append({"Criterion": crit, "p": p_sel,
                        "h (m)": h, "DM-stat": DM, "N-forecasts": N})

robust_df = pd.DataFrame(results)
print("\n===  Diebold-Mariano (Wu-Xia – Our SR)  ===")
print(robust_df.to_string(index=False,
      formatters={"DM-stat": "{:+.2f}".format}))

robust_df.to_excel("dm_robustness_monthly.xlsx", index=False)
print("\nΑποθήκευση: dm_robustness_monthly.xlsx")

import numpy as np, pandas as pd, matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR
from tqdm.notebook import trange

p_max     = 12
horizons  = [1, 3, 6, 12]
blocks    = [3, 6]
subsplits = [("2008-01", "2011-12"), ("2012-01", "2015-12")]

def hac_var(d, L):
    """fixed-b block variance (Andrews)"""
    if len(d) == 0: return np.nan
    block_means = np.array([d[i::L].mean() for i in range(L)])
    return L * block_means.var(ddof=1) / len(d)

def dm_stat(df_wx, df_my, target, p, h, L):
    rmse_wx, rmse_my = [], []
    start = max(p + h + L, df_wx.shape[1] + 1)
    for t in range(start, len(df_wx) - h):
        m_wx = VAR(df_wx.iloc[:t]).fit(p)
        m_my = VAR(df_my.iloc[:t]).fit(p)
        f_wx = m_wx.forecast(df_wx.values[t-p:t], h)[-1, m_wx.names.index(target)]
        f_my = m_my.forecast(df_my.values[t-p:t], h)[-1, m_my.names.index(target)]
        y_obs = df_wx[target].iloc[t + h - 1]
        rmse_wx.append((y_obs - f_wx)**2)
        rmse_my.append((y_obs - f_my)**2)
    d = np.array(rmse_wx) - np.array(rmse_my)
    DM = d.mean() / np.sqrt(hac_var(d, L))
    return DM, len(d)

target = "RGDP"
dm_grid = {h: [] for h in horizons}

for p in range(1, p_max+1):
    for h in horizons:
        DM, _ = dm_stat(df_wx, df_my, target, p, h, L=3)
        dm_grid[h].append(DM)

plt.figure(figsize=(7,4))
for h in horizons:
    plt.plot(range(1, p_max+1), dm_grid[h], marker="o", label=f"h={h}")
plt.axhline(1.96, color="grey", ls="--", lw=.7)
plt.axhline(-1.96, color="grey", ls="--", lw=.7)
plt.xlabel("VAR lag length p"); plt.ylabel("DM-stat (RGDP)")
plt.title("p-sweep: Diebold-Mariano  (positive ⇒ Our SR better)")
plt.legend(); plt.tight_layout(); plt.show()

print("\n===  DM με HAC block = 6 μήνες  (target: RGDP, p=6) ===")
for h in horizons:
    DM, N = dm_stat(df_wx, df_my, "RGDP", p=6, h=h, L=6)
    print(f"h={h:>2}:  DM={DM:+5.2f}   N={N}")

print("\n===  Sub-sample DM  (p=6, block=3) ===")
for (start, end) in subsplits:
    dfx_w = df_wx.loc[start:end]; dfx_m = df_my.loc[start:end]
    DM, N = dm_stat(dfx_w, dfx_m, "RGDP", p=6, h=1, L=3)
    print(f"{start}–{end}:  DM={DM:+5.2f}   N={N}")

alt_targets = ["RGDP", "RHOURS"]
print("\n===  DM για εναλλακτικά target-vars (p=6, h=1, L=3) ===")
for tgt in alt_targets:
    if tgt not in df_wx.columns:
        print(f"{tgt}:  **δεν υπάρχει στη βάση**")
        continue
    DM, N = dm_stat(df_wx, df_my, tgt, p=6, h=1, L=3)
    print(f"{tgt}:  DM={DM:+5.2f}   N={N}")

import numpy as np, matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR
# Out:
# Months in sample: 96   (2008-01-31 00:00:00 → 2015-12-31 00:00:00)
# Wu-Xia VAR(3)  T=93   |   Our VAR(3)  T=93
# boot:   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/83 [00:00<?, ?it/s]
# Rolling 1-step DM = +3.29   (|stat|>1.96 ⇒ 5 %)
# AIC-optimal p = 6   |   BIC-optimal p = 6
#
# ===  Diebold-Mariano (Wu-Xia – Our SR)  ===
# Criterion  p  h (m) DM-stat  N-forecasts
#       AIC  6      1   +7.91           83
#       AIC  6      3   +6.48           81
#       AIC  6      6   +1.09           75
#       AIC  6     12   +1.71           63
#       BIC  6      1   +7.91           83
#       BIC  6      3   +6.48           81
#       BIC  6      6   +1.09           75
#       BIC  6     12   +1.71           63
#
# Αποθήκευση: dm_robustness_monthly.xlsx
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:176: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# ===  DM με HAC block = 6 μήνες  (target: RGDP, p=6) ===
# h= 1:  DM=+3.76   N=82
# h= 3:  DM=+2.52   N=78
# h= 6:  DM=+0.76   N=72
# h=12:  DM=+0.80   N=60
#
# ===  Sub-sample DM  (p=6, block=3) ===
# 2008-01–2011-12:  DM=+2.91   N=35
# 2012-01–2015-12:  DM=-0.29   N=35
#
# ===  DM για εναλλακτικά target-vars (p=6, h=1, L=3) ===
# RGDP:  DM=+7.91   N=83
# RHOURS:  DM=+6.80   N=83

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from statsmodels.tsa.api import VAR
import matplotlib.pyplot as plt

file_path = '/content/favar us.xlsx'
wu_xia_file_path = '/content/wu xia shadow rates.xlsx'

wu_xia_data = pd.ExcelFile(wu_xia_file_path)
wu_xia_us = pd.read_excel(wu_xia_data, sheet_name='Shadow Rates US', skiprows=1)
wu_xia_us.columns = ['Date', 'Wu-Xia Shadow Rate US']
wu_xia_us['Date'] = pd.to_datetime(wu_xia_us['Date'], errors='coerce')
wu_xia_us = wu_xia_us.dropna(subset=['Date']).set_index('Date')

data = pd.ExcelFile(file_path)
shadow_rates_us = pd.read_excel(data, sheet_name='Shadow Rates US', index_col='Date', parse_dates=True)
industrial_prod_us = pd.read_excel(data, sheet_name='Industrial Production US', index_col='Date', parse_dates=True)
cpi_us = pd.read_excel(data, sheet_name='CPI US', index_col='Date', parse_dates=True)
unemployment_us = pd.read_excel(data, sheet_name='Unemployment US', index_col='Date', parse_dates=True)
bond_yields_us_3m = pd.read_excel(data, sheet_name='Bond Yields US 3M', index_col='Date', parse_dates=True)
bond_yields_us_10y = pd.read_excel(data, sheet_name='Bond Yields US 10Y', index_col='Date', parse_dates=True)

us_data_with_wu_xia = pd.concat([
    wu_xia_us,
    shadow_rates_us.rename(columns={'Shadow Rate US': 'Proposed Shadow Rate'}),
    industrial_prod_us,
    cpi_us,
    unemployment_us,
    bond_yields_us_3m,
    bond_yields_us_10y
], axis=1).dropna()

print(us_data_with_wu_xia.columns)

def process_data_for_VAR(data, shadow_rate_col):
    diff_data = data.diff().dropna()
    diff_data.index = pd.date_range(start=diff_data.index[0], periods=len(diff_data), freq='ME')
    standardized_data = (diff_data - diff_data.mean()) / diff_data.std()

    macro_vars = standardized_data.drop(columns=[shadow_rate_col])
    pca = PCA(n_components=3)
    pca_factors = pca.fit_transform(macro_vars)

    factors = pd.DataFrame(pca_factors, index=diff_data.index, columns=['Factor1', 'Factor2', 'Factor3'])
    var_data = pd.concat([factors, diff_data[shadow_rate_col]], axis=1)
    return var_data

us_favar_data_your_shadow = process_data_for_VAR(us_data_with_wu_xia, shadow_rate_col='Proposed Shadow Rate')
us_favar_data_wu_xia_shadow = process_data_for_VAR(us_data_with_wu_xia, shadow_rate_col='Wu-Xia Shadow Rate US')

def fit_VAR_and_analyze(data, lags=2, n_periods=10):
    """
    • Fits a VAR(lags) to the input DataFrame.
    • Prints the full coefficient tables, information criteria,
      and residual-correlation matrix.
    • Returns both the fitted VAR object and its orthogonalised IRF object.
    """
    model     = VAR(data)
    var_model = model.fit(lags)

    print("\n=== VAR({}) estimation results ===".format(lags))
    print(var_model.summary())
    print("\nCorrelation matrix of residuals")
    print(var_model.resid.corr())

    irf = var_model.irf(n_periods)
    return var_model, irf


var_your_shadow, irf_your_shadow = fit_VAR_and_analyze(
    us_favar_data_your_shadow, lags=2, n_periods=10)

var_wu_xia, irf_wu_xia_shadow = fit_VAR_and_analyze(
    us_favar_data_wu_xia_shadow, lags=2, n_periods=10)

print("Impulse Response for the proposed Shadow Rate (US):")
irf_your_shadow.plot(orth=True)
plt.title("Impulse Response for the proposed Shadow Rate (US)")
plt.show()

print("Impulse Response for Wu-Xia Shadow Rate (US):")
irf_wu_xia_shadow.plot(orth=True)
plt.title("Impulse Response for Wu-Xia Shadow Rate (US)")
plt.show()

def calculate_cumulative_irf(irf_object, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_object.orth_irfs[:n_periods]
    response_names = irf_object.model.names

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            response_values = irf_matrix[:, j, i]
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(response_values))

    return cumulative_irf

cumulative_irf_your_shadow = calculate_cumulative_irf(irf_your_shadow, n_periods=10)
cumulative_irf_wu_xia_shadow = calculate_cumulative_irf(irf_wu_xia_shadow, n_periods=10)

comparison_df = pd.DataFrame({
    "Proposed Shadow Rate": cumulative_irf_your_shadow,
    "Wu-Xia Shadow Rate": cumulative_irf_wu_xia_shadow
}).T

comparison_df.loc['Difference'] = (
    comparison_df.loc['Proposed Shadow Rate'] - comparison_df.loc['Wu-Xia Shadow Rate']
)

print("Cumulative Impulse Responses Comparison for US:")
print(comparison_df)

output_file = 'cumulative_irf_comparison_us.csv'
comparison_df.to_csv(output_file)
print(f"Comparison data saved as '{output_file}' in the current working directory.")

comparison_df.loc["Proposed Shadow Rate"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="Proposed Shadow Rate")
comparison_df.loc["Wu-Xia Shadow Rate"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="Wu-Xia Shadow Rate", color="orange")
plt.title("Cumulative Impulse Responses Comparison (US)")
plt.xlabel("Response → Impulse")
plt.ylabel("Cumulative IRF")
plt.legend()
plt.tight_layout()
plt.show()

# !pip install statsmodels

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR

file_path = '/content/new entry us.xlsx'
xls = pd.ExcelFile(file_path)

shadow_us = pd.read_excel(xls, sheet_name='My shadow rates US', parse_dates=['Date'])
inflation_us = pd.read_excel(xls, sheet_name='Inflation US', parse_dates=['Date'])
gdp_us = pd.read_excel(xls, sheet_name='Real GDP US', parse_dates=['Date'])

shadow_us.set_index('Date', inplace=True)
inflation_us.set_index('Date', inplace=True)
gdp_us.set_index('Date', inplace=True)

data_us = pd.concat([shadow_us, inflation_us, gdp_us], axis=1).dropna()

print("\nMerged Data Columns (US):")
print(data_us.columns)

data_us['INF US'] = data_us['INF US'].pct_change() * 100
data_us['GDP US'] = data_us['GDP US'].pct_change() * 100

data_us = data_us.dropna()

print("\nAfter transformations (first few rows):")
print(data_us.head())

def prepare_var_data(df):
    standardized_data = (df - df.mean()) / df.std()
    return standardized_data

var_data_us = prepare_var_data(data_us)

model_us = VAR(var_data_us)
lag_order = 2
results_us = model_us.fit(lag_order)

print("\nVAR Model Summary (US):")
print(results_us.summary())

n_periods = 20
irf_us = results_us.irf(n_periods)

print("\nImpulse Response Functions (US system):")
irf_us.plot(orth=True)
plt.suptitle('Impulse Response Functions - Final Shadow Rate System (US)')
plt.show()

def calculate_cumulative_irf(irf_obj, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_obj.orth_irfs[:n_periods]
    response_names = irf_obj.model.names

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(irf_matrix[:, j, i]))

    return cumulative_irf

cumulative_irf_us = calculate_cumulative_irf(irf_us)
cumulative_irf_us_df = pd.DataFrame(cumulative_irf_us, index=['Cumulative IRF'])

print("\nCumulative IRF Results (US):")
print(cumulative_irf_us_df.T)

cumulative_irf_us_df.T.to_excel('cumulative_irf_final_shadow_us.xlsx')
print("\nCumulative IRF saved to 'cumulative_irf_final_shadow_us.xlsx'.")
# Out:
# Index(['Wu-Xia Shadow Rate US', 'Proposed Shadow Rate', 'Ind Prod US',
#        'CPI US', 'Unemployment US', 'Bond Yield US 3M', 'Bond Yield US 10Y'],
#       dtype='object')
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Aug, 2025
# Time:                     13:08:40
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -1.40082
# Nobs:                     112.000    HQIC:                  -1.92009
# Log likelihood:          -472.306    FPE:                   0.102979
# AIC:                     -2.27462    Det(Omega_mle):       0.0755926
# --------------------------------------------------------------------
# Results for equation Factor1
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.013623         0.160391           -0.085           0.932
# L1.Factor1                     -0.063666         0.204719           -0.311           0.756
# L1.Factor2                     -0.039458         0.182487           -0.216           0.829
# L1.Factor3                      0.031689         0.189760            0.167           0.867
# L1.Proposed Shadow Rate        -0.463741         0.675573           -0.686           0.492
# L2.Factor1                     -0.181574         0.209136           -0.868           0.385
# L2.Factor2                     -0.120201         0.174835           -0.688           0.492
# L2.Factor3                      0.068658         0.191792            0.358           0.720
# L2.Proposed Shadow Rate        -1.048812         0.707961           -1.481           0.138
# ==========================================================================================
#
# Results for equation Factor2
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.103296         0.104289           -0.990           0.322
# L1.Factor1                      0.381686         0.133112            2.867           0.004
# L1.Factor2                     -0.284358         0.118656           -2.396           0.017
# L1.Factor3                     -0.126008         0.123385           -1.021           0.307
# L1.Proposed Shadow Rate         1.415739         0.439268            3.223           0.001
# L2.Factor1                      0.269262         0.135984            1.980           0.048
# L2.Factor2                     -0.129870         0.113680           -1.142           0.253
# L2.Factor3                     -0.042024         0.124706           -0.337           0.736
# L2.Proposed Shadow Rate         1.307932         0.460328            2.841           0.004
# ==========================================================================================
#
# Results for equation Factor3
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.017017         0.080399           -0.212           0.832
# L1.Factor1                      0.009147         0.102619            0.089           0.929
# L1.Factor2                     -0.109637         0.091475           -1.199           0.231
# L1.Factor3                      0.333035         0.095120            3.501           0.000
# L1.Proposed Shadow Rate        -0.231286         0.338642           -0.683           0.495
# L2.Factor1                      0.244366         0.104833            2.331           0.020
# L2.Factor2                     -0.138733         0.087639           -1.583           0.113
# L2.Factor3                      0.011823         0.096139            0.123           0.902
# L2.Proposed Shadow Rate         0.753191         0.354877            2.122           0.034
# ==========================================================================================
#
# Results for equation Proposed Shadow Rate
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                           0.038818         0.048392            0.802           0.422
# L1.Factor1                      0.017442         0.061767            0.282           0.778
# L1.Factor2                     -0.047274         0.055059           -0.859           0.391
# L1.Factor3                     -0.052770         0.057254           -0.922           0.357
# L1.Proposed Shadow Rate         0.147239         0.203830            0.722           0.470
# L2.Factor1                      0.106531         0.063100            1.688           0.091
# L2.Factor2                     -0.001513         0.052750           -0.029           0.977
# L2.Factor3                     -0.037674         0.057867           -0.651           0.515
# L2.Proposed Shadow Rate         0.660654         0.213603            3.093           0.002
# ==========================================================================================
#
# Correlation matrix of residuals
#                          Factor1   Factor2   Factor3  Proposed Shadow Rate
# Factor1                 1.000000  0.241899  0.002887             -0.818556
# Factor2                 0.241899  1.000000  0.025535              0.140215
# Factor3                 0.002887  0.025535  1.000000              0.014994
# Proposed Shadow Rate   -0.818556  0.140215  0.014994              1.000000
#
#
#
#
# Correlation matrix of residuals
#                        Factor1   Factor2   Factor3  Proposed Shadow Rate
# Factor1               1.000000  0.241899  0.002887             -0.818556
# Factor2               0.241899  1.000000  0.025535              0.140215
# Factor3               0.002887  0.025535  1.000000              0.014994
# Proposed Shadow Rate -0.818556  0.140215  0.014994              1.000000
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Aug, 2025
# Time:                     13:08:40
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                  -0.374916
# Nobs:                     112.000    HQIC:                 -0.894189
# Log likelihood:          -529.756    FPE:                   0.287271
# AIC:                     -1.24872    Det(Omega_mle):        0.210874
# --------------------------------------------------------------------
# Results for equation Factor1
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                           -0.090182         0.160331           -0.562           0.574
# L1.Factor1                       0.086060         0.108822            0.791           0.429
# L1.Factor2                      -0.105982         0.146369           -0.724           0.469
# L1.Factor3                       0.074727         0.203876            0.367           0.714
# L1.Wu-Xia Shadow Rate US         0.149992         0.517560            0.290           0.772
# L2.Factor1                       0.112592         0.107345            1.049           0.294
# L2.Factor2                      -0.294589         0.146459           -2.011           0.044
# L2.Factor3                      -0.277573         0.205604           -1.350           0.177
# L2.Wu-Xia Shadow Rate US        -0.308701         0.520727           -0.593           0.553
# ===========================================================================================
#
# Results for equation Factor2
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                            0.029656         0.106678            0.278           0.781
# L1.Factor1                       0.012709         0.072406            0.176           0.861
# L1.Factor2                      -0.046943         0.097389           -0.482           0.630
# L1.Factor3                       0.154174         0.135652            1.137           0.256
# L1.Wu-Xia Shadow Rate US         0.049666         0.344365            0.144           0.885
# L2.Factor1                      -0.088357         0.071424           -1.237           0.216
# L2.Factor2                       0.023290         0.097449            0.239           0.811
# L2.Factor3                       0.110608         0.136801            0.809           0.419
# L2.Wu-Xia Shadow Rate US         0.103914         0.346473            0.300           0.764
# ===========================================================================================
#
# Results for equation Factor3
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                           -0.033418         0.075634           -0.442           0.659
# L1.Factor1                       0.040500         0.051336            0.789           0.430
# L1.Factor2                      -0.033413         0.069048           -0.484           0.628
# L1.Factor3                       0.087937         0.096177            0.914           0.361
# L1.Wu-Xia Shadow Rate US         0.252314         0.244154            1.033           0.301
# L2.Factor1                      -0.019851         0.050639           -0.392           0.695
# L2.Factor2                      -0.025424         0.069091           -0.368           0.713
# L2.Factor3                       0.067334         0.096992            0.694           0.488
# L2.Wu-Xia Shadow Rate US         0.177768         0.245648            0.724           0.469
# ===========================================================================================
#
# Results for equation Wu-Xia Shadow Rate US
# ===========================================================================================
#                               coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------
# const                            0.039448         0.035713            1.105           0.269
# L1.Factor1                       0.001516         0.024240            0.063           0.950
# L1.Factor2                       0.020255         0.032604            0.621           0.534
# L1.Factor3                       0.052870         0.045413            1.164           0.244
# L1.Wu-Xia Shadow Rate US         0.229774         0.115286            1.993           0.046
# L2.Factor1                      -0.014439         0.023911           -0.604           0.546
# L2.Factor2                       0.020250         0.032624            0.621           0.535
# L2.Factor3                      -0.041942         0.045798           -0.916           0.360
# L2.Wu-Xia Shadow Rate US         0.130554         0.115991            1.126           0.260
# ===========================================================================================
#
# Correlation matrix of residuals
#                           Factor1   Factor2   Factor3  Wu-Xia Shadow Rate US
# Factor1                  1.000000  0.158883 -0.077018              -0.509557
# Factor2                  0.158883  1.000000  0.011948               0.121897
# Factor3                 -0.077018  0.011948  1.000000               0.132302
# Wu-Xia Shadow Rate US   -0.509557  0.121897  0.132302               1.000000
#
#
#
#
# Correlation matrix of residuals
#                         Factor1   Factor2   Factor3  Wu-Xia Shadow Rate US
# Factor1                1.000000  0.158883 -0.077018              -0.509557
# Factor2                0.158883  1.000000  0.011948               0.121897
# Factor3               -0.077018  0.011948  1.000000               0.132302
# Wu-Xia Shadow Rate US -0.509557  0.121897  0.132302               1.000000
# Impulse Response for the proposed Shadow Rate (US):
# Impulse Response for Wu-Xia Shadow Rate (US):
# Cumulative Impulse Responses Comparison for US:
#                       Factor1 → Factor1  Factor2 → Factor1  Factor3 → Factor1  \
# Proposed Shadow Rate           2.163904           0.710144           0.353320
# Wu-Xia Shadow Rate             2.254996           0.447413           0.205562
# Difference                    -0.091092           0.262732           0.147758
#
#                       Proposed Shadow Rate → Factor1  Factor1 → Factor2  \
# Proposed Shadow Rate                         0.70135           0.581729
# Wu-Xia Shadow Rate                               NaN           0.623536
# Difference                                       NaN          -0.041807
#
#                       Factor2 → Factor2  Factor3 → Factor2  \
# Proposed Shadow Rate           1.236404           0.385298
# Wu-Xia Shadow Rate             1.253419           0.075721
# Difference                    -0.017016           0.309577
#
#                       Proposed Shadow Rate → Factor2  Factor1 → Factor3  \
# Proposed Shadow Rate                        0.405918           0.402942
# Wu-Xia Shadow Rate                               NaN           0.528358
# Difference                                       NaN          -0.125416
#
#                       Factor2 → Factor3  ...  Factor2 → Proposed Shadow Rate  \
# Proposed Shadow Rate           0.377376  ...                        0.674935
# Wu-Xia Shadow Rate             0.289000  ...                             NaN
# Difference                     0.088376  ...                             NaN
#
#                       Factor3 → Proposed Shadow Rate  \
# Proposed Shadow Rate                        0.322474
# Wu-Xia Shadow Rate                               NaN
# Difference                                       NaN
#
#                       Proposed Shadow Rate → Proposed Shadow Rate  \
# Proposed Shadow Rate                                     0.515551
# Wu-Xia Shadow Rate                                            NaN
# Difference                                                    NaN
#
#                       Wu-Xia Shadow Rate US → Factor1  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.351353
# Difference                                        NaN
#
#                       Wu-Xia Shadow Rate US → Factor2  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.205852
# Difference                                        NaN
#
#                       Wu-Xia Shadow Rate US → Factor3  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.114998
# Difference                                        NaN
#
#                       Factor1 → Wu-Xia Shadow Rate US  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.322401
# Difference                                        NaN
#
#                       Factor2 → Wu-Xia Shadow Rate US  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.152109
# Difference                                        NaN
#
#                       Factor3 → Wu-Xia Shadow Rate US  \
# Proposed Shadow Rate                              NaN
# Wu-Xia Shadow Rate                           0.239116
# Difference                                        NaN
#
#                       Wu-Xia Shadow Rate US → Wu-Xia Shadow Rate US
# Proposed Shadow Rate                                            NaN
# Wu-Xia Shadow Rate                                         0.503806
# Difference                                                      NaN
#
# [3 rows x 23 columns]
# Comparison data saved as 'cumulative_irf_comparison_us.csv' in the current working directory.
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.1)
# Requirement already satisfied: numpy<2,>=1.18 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.0->statsmodels) (1.17.0)
#
# Merged Data Columns (US):
# Index(['Final Shadow Rate', 'INF US', 'GDP US'], dtype='object')
#
# After transformations (first few rows):
#             Final Shadow Rate    INF US    GDP US
# Date
# 2009-01-01          -0.733897 -2.507238 -1.134874
# 2009-04-01          -0.078491  0.993166 -0.178651
# 2009-07-01          -0.780591  0.989964  0.351192
# 2009-10-01          -1.727421  0.383560  1.080914
# 2010-01-01          -1.242671  0.235918  0.484501
#
# VAR Model Summary (US):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Aug, 2025
# Time:                     13:08:51
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -2.65085
# Nobs:                     60.0000    HQIC:                  -3.09715
# Log likelihood:          -132.893    FPE:                  0.0340247
# AIC:                     -3.38387    Det(Omega_mle):       0.0244356
# --------------------------------------------------------------------
# Results for equation Final Shadow Rate
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.025667         0.028956            0.886           0.375
# L1.Final Shadow Rate         1.340124         0.135062            9.922           0.000
# L1.INF US                    0.050098         0.036321            1.379           0.168
# L1.GDP US                   -0.001944         0.030751           -0.063           0.950
# L2.Final Shadow Rate        -0.360321         0.143013           -2.519           0.012
# L2.INF US                    0.063917         0.030750            2.079           0.038
# L2.GDP US                   -0.011454         0.030498           -0.376           0.707
# =======================================================================================
#
# Results for equation INF US
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.017803         0.121430            0.147           0.883
# L1.Final Shadow Rate         0.601322         0.566403            1.062           0.288
# L1.INF US                    0.172693         0.152316            1.134           0.257
# L1.GDP US                   -0.122174         0.128958           -0.947           0.343
# L2.Final Shadow Rate        -0.621883         0.599747           -1.037           0.300
# L2.INF US                   -0.026504         0.128955           -0.206           0.837
# L2.GDP US                   -0.027881         0.127899           -0.218           0.827
# =======================================================================================
#
# Results for equation GDP US
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.077565         0.127184            0.610           0.542
# L1.Final Shadow Rate        -1.114458         0.593239           -1.879           0.060
# L1.INF US                    0.124563         0.159533            0.781           0.435
# L1.GDP US                   -0.301528         0.135068           -2.232           0.026
# L2.Final Shadow Rate         1.118235         0.628164            1.780           0.075
# L2.INF US                    0.091823         0.135065            0.680           0.497
# L2.GDP US                   -0.170720         0.133959           -1.274           0.203
# =======================================================================================
#
# Correlation matrix of residuals
#                      Final Shadow Rate    INF US    GDP US
# Final Shadow Rate             1.000000  0.424887  0.433858
# INF US                        0.424887  1.000000  0.238947
# GDP US                        0.433858  0.238947  1.000000
#
#
#
#
# Impulse Response Functions (US system):
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# Cumulative IRF Results (US):
#                                        Cumulative IRF
# Final Shadow Rate → Final Shadow Rate        3.644580
# INF US → Final Shadow Rate                   0.759273
# GDP US → Final Shadow Rate                   0.842649
# Final Shadow Rate → INF US                   1.271547
# INF US → INF US                              1.078137
# GDP US → INF US                              0.269518
# Final Shadow Rate → GDP US                   0.221656
# INF US → GDP US                              0.143894
# GDP US → GDP US                              1.295814
#
# Cumulative IRF saved to 'cumulative_irf_final_shadow_us.xlsx'.
